# %%
from helper import generate_periodic_ising_infidelity_data, plot_error_vs_depth

# %% [markdown]
# Define parameters

# %%
J = 1
g = 0.5
dt = 0.1
num_qubits = 16
pad = 2

# thresholds = [0]
max_bonds = [8, 16, 32, 64]
thresholds = [0]
# max_bonds = [64]
timesteps_list = [1, 5, *range(10, 110, 10)]

# %%
results = generate_periodic_ising_infidelity_data(num_qubits, J, g, dt, pad, thresholds, max_bonds, timesteps_list)
# Out:
# Max Bond 8
# Threshold 0
# TDVP Max Bond 8
# TEBD Max Bond 4
# TDVP Max Bond 8
# TEBD Max Bond 8
# TDVP Max Bond 8
# TEBD Max Bond 8
# TDVP Max Bond 8
# TEBD Max Bond 8
# TDVP Max Bond 8
# TEBD Max Bond 8
# TDVP Max Bond 8
# TEBD Max Bond 8
# TDVP Max Bond 8
# TEBD Max Bond 8
# TDVP Max Bond 8
# TEBD Max Bond 8
# TDVP Max Bond 8
# TEBD Max Bond 8
# TDVP Max Bond 8
# TEBD Max Bond 8
# TDVP Max Bond 8
# TEBD Max Bond 8
# TDVP Max Bond 8
# TEBD Max Bond 8
# Max Bond 16
# Threshold 0
# TDVP Max Bond 16
# TEBD Max Bond 4
# TDVP Max Bond 16
# TEBD Max Bond 15
# TDVP Max Bond 16
# TEBD Max Bond 16
# TDVP Max Bond 16
# TEBD Max Bond 16
# TDVP Max Bond 16
# TEBD Max Bond 16
# TDVP Max Bond 16
# TEBD Max Bond 16
# TDVP Max Bond 16
# TEBD Max Bond 16
# TDVP Max Bond 16
# TEBD Max Bond 16
# TDVP Max Bond 16
# TEBD Max Bond 16
# TDVP Max Bond 16
# TEBD Max Bond 16
# TDVP Max Bond 16
# TEBD Max Bond 16
# TDVP Max Bond 16
# TEBD Max Bond 16
# Max Bond 32
# Threshold 0
# TDVP Max Bond 16
# ...

# %%
plot_error_vs_depth(results, thresholds, max_bonds)
