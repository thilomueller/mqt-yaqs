# %%
from __future__ import annotations

from correlator_utils import generate_heisenberg_error_data, plot_error_vs_depth

# %% [markdown]
# Define parameters

# %%
J = 1
g = 1
dt = 0.1
num_qubits = 16

min_bonds = [2, 4, 8, 16]
thresholds = [0]
# max_bonds = [64]
timesteps_list = [1, 5, *range(10, 110, 10)]
timesteps_list = [*range(1, 11)]

# %%
results = generate_heisenberg_error_data(num_qubits, J, g, dt, min_bonds, timesteps_list)
# Out:
# Timesteps 1
# Timesteps 2
# Timesteps 3
# Timesteps 4
# Timesteps 5
# Timesteps 6
# Timesteps 7
# Timesteps 8
# Timesteps 9
# Timesteps 10
# Timesteps 1
# Timesteps 2
# Timesteps 3
# Timesteps 4
# Timesteps 5
# Timesteps 6
# Timesteps 7
# Timesteps 8
# Timesteps 9
# Timesteps 10
# Timesteps 1
# Timesteps 2
# Timesteps 3
# Timesteps 4
# Timesteps 5
# Timesteps 6
# Timesteps 7
# Timesteps 8
# Timesteps 9
# Timesteps 10
# Timesteps 1
# Timesteps 2
# Timesteps 3
# Timesteps 4
# Timesteps 5
# Timesteps 6
# Timesteps 7
# Timesteps 8
# Timesteps 9
# Timesteps 10

# %%
plot_error_vs_depth(results, min_bonds)
