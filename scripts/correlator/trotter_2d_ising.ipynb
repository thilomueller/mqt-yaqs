# %%
from correlator_utils import generate_error_data, plot_error_vs_depth

from mqt.yaqs.core.libraries.circuit_library import create_2d_ising_circuit

# %% [markdown]
# Define parameters

# %%
J = 1
g = 1
dt = 0.1
num_rows = 4
num_cols = 4
pad = 1

min_bonds = [2, 4, 8, 16, 32]
thresholds = [0]
# max_bonds = [64]
# timesteps_list = [1, 5, *range(10, 110, 10)]
timesteps_list = [*range(1, 6)]

# %%
results = generate_error_data(create_2d_ising_circuit, (num_rows, num_cols, J, g, dt),
                    min_bonds=min_bonds, timesteps=timesteps_list, periodic=True)
# Out:
# Min bond dim 2
#   Timesteps = 1
#   Timesteps = 2
#   Timesteps = 3
#   Timesteps = 4
#   Timesteps = 5
# Min bond dim 4
#   Timesteps = 1
#   Timesteps = 2
#   Timesteps = 3
#   Timesteps = 4
#   Timesteps = 5
# Min bond dim 8
#   Timesteps = 1
#   Timesteps = 2
#   Timesteps = 3
#   Timesteps = 4
#   Timesteps = 5
# Min bond dim 16
#   Timesteps = 1
#   Timesteps = 2
#   Timesteps = 3
#   Timesteps = 4
#   Timesteps = 5
# Min bond dim 32
#   Timesteps = 1
#   Timesteps = 2
#   Timesteps = 3
#   Timesteps = 4
#   Timesteps = 5

# %%
plot_error_vs_depth(results, min_bonds)
