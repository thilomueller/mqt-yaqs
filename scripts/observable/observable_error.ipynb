# %%
from helper import generate_heisenberg_observable_data, plot_error_vs_depth

# %% [markdown]
# Define parameters

# %%
J = 1
g = 0.5
dt = 0.1
num_qubits = 12
pad = 2

# thresholds = [1e-8]
max_bonds = [8, 16, 32]
thresholds = [0]
# max_bonds = [64]
timesteps_list = [1, 5, *range(10, 110, 10)]

# %%
results = generate_heisenberg_observable_data(num_qubits, J, g, dt, pad, thresholds, max_bonds, timesteps_list)
# Out:
# Max Bond 8
# Threshold 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 results = generate_heisenberg_observable_data(num_qubits, J, g, dt, pad, thresholds, max_bonds, timesteps_list)
#
# File c:\Users\aaron\OneDrive\Documents\GitHub\mqt-yaqs\scripts\observable\helper.py:162, in generate_heisenberg_observable_data(num_qubits, J, h, dt, pad, thresholds, max_bonds, timesteps_list)
#     159 exact_sv, exact_exp_val = state_vector_simulator(circ2)
#     161 # Run both simulators
# --> 162 mps, tdvp_sv, tdvp_exp_val = tdvp_simulator(circ, max_bond, threshold, pad, initial_state=mps)
#     163 tebd_sv, tebd_exp_val = tebd_simulator(circ2, max_bond, threshold)
#     165 # Compute the absolute error relative to the exact solution
#     166 # Second absolute is to stop numerical errors in squaring small floats
#
# File c:\Users\aaron\OneDrive\Documents\GitHub\mqt-yaqs\scripts\observable\helper.py:67, in tdvp_simulator(circ, max_bond, threshold, pad, initial_state)
#      65 if initial_state is None:
#      66     initial_state = MPS(length=circ.num_qubits)
# ---> 67     initial_state.pad_bond_dimension(pad)
#      68 measurements = [Observable(Z(), circ.num_qubits//2)]
#      69 sim_params = StrongSimParams(measurements, num_traj=1, max_bond_dim=max_bond, threshold=threshold, get_state=True, window_size=1)
#
# File ~\OneDrive\Documents\GitHub\mqt-yaqs\src\mqt\yaqs\core\data_structures\networks.py:227, in MPS.pad_bond_dimension(self, target_dim)
#     225 if chi_l > left_target or chi_r > right_target:
#     226     msg = "Target bond dim must be at least current bond dim."
# --> 227     raise ValueError(msg)
#     229 # allocate new tensor and copy original data
#     230 new_tensor = np.zeros((phys, left_target, right_target), dtype=tensor.dtype)
#
# ValueError: Target bond dim must be at least current bond dim.

# %%
plot_error_vs_depth(results, max_bonds)
