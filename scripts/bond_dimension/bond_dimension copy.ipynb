# %%
from __future__ import annotations

from helper import generate_periodic_heisenberg_observable_data, plot_bond_heatmaps

# %% [markdown]
# Define parameters

# %%
J = 1
g = 0.5
dt = 0.1
num_qubits = 36
pad = 1

max_bonds = [512]
thresholds = [0]
timesteps_list = [*range(1, 6)]

# %%
results = generate_periodic_heisenberg_observable_data(num_qubits, J, g, dt, pad, thresholds, max_bonds, timesteps_list)
# Out:
# Timesteps 1
# Timesteps 2
# Timesteps 3
# Timesteps 4
# Timesteps 5

# %%
plot_bond_heatmaps(results, bond_dim=max_bonds[0], threshold=0)
# Out:
# [0.94105691 1.49805951 1.83524904 2.12830189 2.4523212 ]
# c:\Users\aaron\OneDrive\Documents\GitHub\mqt-yaqs\scripts\bond_dimension\helper.py:286: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
