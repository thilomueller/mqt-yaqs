# %%
from __future__ import annotations

from helper import generate_periodic_heisenberg_observable_data, plot_error_vs_depth

# %% [markdown]
# Define parameters

# %%
J = 1
g = 0.5
dt = 0.1
num_qubits = 11
pad = 1

# thresholds = [0]
max_bonds = [256]
thresholds = [0]
# max_bonds = [64]
# timesteps_list = [1, 5, *range(10, 110, 10)]
timesteps_list = [*range(1, 6)]

# %%
results = generate_periodic_heisenberg_observable_data(num_qubits, J, g, dt, pad, thresholds, max_bonds, timesteps_list)

# %%
plot_error_vs_depth(results, max_bonds)
